# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import requests 
import time 
from scipy.stats import linregress
import urllib

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key


# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# openweatherMap API Key
api_key = "272ba3972ff73e916b323a51a2eaa1a8"

# Starting URL for Weather Map API Call
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        

    # Create endpoint URL with each city
    city_url = url  + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()


        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | kabinda
# Processing Record 7 of Set 1 | luorong
# Processing Record 8 of Set 1 | sangar
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | nyahururu
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | sao manuel
# Processing Record 14 of Set 1 | irricana
# Processing Record 15 of Set 1 | vargem grande
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | adrar
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | nacala
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | abdanan
# Processing Record 22 of Set 1 | verkhoyansk
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | strezhevoy
# Processing Record 26 of Set 1 | airai
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | clyde river
# Processing Record 29 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 30 of Set 1 | cayenne
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | nome
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | klichka
# Processing Record 37 of Set 1 | los llanos de aridane
# Processing Record 38 of Set 1 | tuatapere
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | husavik
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | grand island
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | dingle
# Processing Record 45 of Set 1 | taguatinga
# Processing Record 46 of Set 1 | lagoa
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | tyukhtet
# Processing Record 49 of Set 1 | lebedyan
# Processing Record 50 of Set 1 | tiznit
# Processing Record 0 of Set 2 | labuhan
# Processing Record 1 of Set 2 | college
# Processing Record 2 of Set 2 | sambava
# Processing Record 3 of Set 2 | phan thiet
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | katha
# City not found. Skipping...
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | darhan
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | bemidji
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | constitucion
# Processing Record 13 of Set 2 | krasnousolskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | luderitz
# Processing Record 16 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 2 | half moon bay
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | mafinga
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | comodoro rivadavia
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | susuman
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | indramayu
# Processing Record 28 of Set 2 | angol
# Processing Record 29 of Set 2 | kidal
# Processing Record 30 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 2 | salalah
# Processing Record 35 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | pangnirtung
# Processing Record 38 of Set 2 | burica
# City not found. Skipping...
# Processing Record 39 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 2 | tenenkou
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | saldanha
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | maunatlala
# Processing Record 45 of Set 2 | haapiti
# Processing Record 46 of Set 2 | seoul
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | east london
# Processing Record 0 of Set 3 | palu
# Processing Record 1 of Set 3 | karratha
# Processing Record 2 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 3 | kathmandu
# Processing Record 4 of Set 3 | gazli
# Processing Record 5 of Set 3 | esperance
# Processing Record 6 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 3 | ambilobe
# Processing Record 8 of Set 3 | olafsvik
# Processing Record 9 of Set 3 | omsukchan
# Processing Record 10 of Set 3 | vardo
# Processing Record 11 of Set 3 | shakawe
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | sistranda
# Processing Record 14 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 3 | hovd
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | peleduy
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | rio grande
# Processing Record 24 of Set 3 | plettenberg bay
# Processing Record 25 of Set 3 | makakilo city
# Processing Record 26 of Set 3 | dubbo
# Processing Record 27 of Set 3 | lavumisa
# Processing Record 28 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 3 | paramonga
# Processing Record 30 of Set 3 | knysna
# Processing Record 31 of Set 3 | fonte boa
# Processing Record 32 of Set 3 | moche
# Processing Record 33 of Set 3 | tuktoyaktuk
# Processing Record 34 of Set 3 | taltal
# Processing Record 35 of Set 3 | odessa
# Processing Record 36 of Set 3 | albany
# Processing Record 37 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 3 | norton shores
# Processing Record 39 of Set 3 | kailua
# Processing Record 40 of Set 3 | verkhniye achaluki
# Processing Record 41 of Set 3 | valparai
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | pinotepa nacional
# Processing Record 44 of Set 3 | abu samrah
# Processing Record 45 of Set 3 | valparaiso
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | saraland
# Processing Record 49 of Set 3 | pangody
# Processing Record 0 of Set 4 | kapaa
# Processing Record 1 of Set 4 | lompoc
# Processing Record 2 of Set 4 | vydrino
# Processing Record 3 of Set 4 | sur
# Processing Record 4 of Set 4 | pittsfield
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | kruisfontein
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | cape town
# Processing Record 9 of Set 4 | george
# Processing Record 10 of Set 4 | georgetown
# Processing Record 11 of Set 4 | geraldton
# Processing Record 12 of Set 4 | broome
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 4 | bandarbeyla
# Processing Record 15 of Set 4 | xichang
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | killybegs
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | richards bay
# Processing Record 22 of Set 4 | alta floresta
# Processing Record 23 of Set 4 | xocali
# Processing Record 24 of Set 4 | kazanskoye
# Processing Record 25 of Set 4 | talara
# Processing Record 26 of Set 4 | guerrero negro
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | kalga
# Processing Record 29 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 4 | trelew
# Processing Record 31 of Set 4 | jinchang
# Processing Record 32 of Set 4 | narsaq
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | bhikhi
# Processing Record 35 of Set 4 | ca mau
# Processing Record 36 of Set 4 | havre-saint-pierre
# Processing Record 37 of Set 4 | beringovskiy
# Processing Record 38 of Set 4 | aykhal
# Processing Record 39 of Set 4 | moengo
# Processing Record 40 of Set 4 | port keats
# Processing Record 41 of Set 4 | kushalgarh
# Processing Record 42 of Set 4 | imphal
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 4 | taoudenni
# Processing Record 46 of Set 4 | longyearbyen
# Processing Record 47 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 48 of Set 4 | impfondo
# Processing Record 49 of Set 4 | kutum
# Processing Record 0 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 1 of Set 5 | litovko
# Processing Record 2 of Set 5 | coihaique
# Processing Record 3 of Set 5 | nantucket
# Processing Record 4 of Set 5 | inhambane
# Processing Record 5 of Set 5 | mahebourg
# Processing Record 6 of Set 5 | puerto escondido
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | saint anthony
# Processing Record 9 of Set 5 | saint-pierre
# Processing Record 10 of Set 5 | solms
# Processing Record 11 of Set 5 | port macquarie
# Processing Record 12 of Set 5 | evensk
# Processing Record 13 of Set 5 | the valley
# Processing Record 14 of Set 5 | lafayette
# Processing Record 15 of Set 5 | bandar-e lengeh
# Processing Record 16 of Set 5 | sitka
# Processing Record 17 of Set 5 | atocha
# Processing Record 18 of Set 5 | wamba
# Processing Record 19 of Set 5 | port blair
# Processing Record 20 of Set 5 | cherskiy
# Processing Record 21 of Set 5 | paamiut
# Processing Record 22 of Set 5 | berdigestyakh
# Processing Record 23 of Set 5 | palauig
# Processing Record 24 of Set 5 | davila
# Processing Record 25 of Set 5 | thompson
# Processing Record 26 of Set 5 | praia da vitoria
# Processing Record 27 of Set 5 | san luis
# Processing Record 28 of Set 5 | dudinka
# Processing Record 29 of Set 5 | jizan
# Processing Record 30 of Set 5 | kelvington
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | hamilton
# Processing Record 33 of Set 5 | enshi
# Processing Record 34 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 5 | belaya gora
# Processing Record 36 of Set 5 | maningrida
# Processing Record 37 of Set 5 | calama
# Processing Record 38 of Set 5 | maniitsoq
# Processing Record 39 of Set 5 | sinnamary
# Processing Record 40 of Set 5 | arona
# Processing Record 41 of Set 5 | zhaotong
# Processing Record 42 of Set 5 | asau
# Processing Record 43 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 5 | rocha
# Processing Record 45 of Set 5 | kimamba
# Processing Record 46 of Set 5 | san cristobal
# Processing Record 47 of Set 5 | deputatskiy
# Processing Record 48 of Set 5 | goderich
# Processing Record 49 of Set 5 | tiksi
# Processing Record 0 of Set 6 | ust-nera
# Processing Record 1 of Set 6 | poya
# Processing Record 2 of Set 6 | kodiak
# Processing Record 3 of Set 6 | rantepao
# Processing Record 4 of Set 6 | torbay
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | rabak
# Processing Record 7 of Set 6 | shuyskoye
# Processing Record 8 of Set 6 | martapura
# Processing Record 9 of Set 6 | el vigia
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | baryshivka
# Processing Record 12 of Set 6 | kiunga
# Processing Record 13 of Set 6 | ahipara
# Processing Record 14 of Set 6 | manjacaze
# Processing Record 15 of Set 6 | vila franca do campo
# Processing Record 16 of Set 6 | okhotsk
# Processing Record 17 of Set 6 | sosnovka
# Processing Record 18 of Set 6 | tynda
# Processing Record 19 of Set 6 | leshukonskoye
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | talnakh
# Processing Record 22 of Set 6 | namibe
# Processing Record 23 of Set 6 | marzuq
# Processing Record 24 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 6 | appingedam
# Processing Record 26 of Set 6 | sola
# Processing Record 27 of Set 6 | bud
# Processing Record 28 of Set 6 | alyangula
# Processing Record 29 of Set 6 | amos
# Processing Record 30 of Set 6 | thiruvananthapuram
# Processing Record 31 of Set 6 | upata
# Processing Record 32 of Set 6 | bayir
# Processing Record 33 of Set 6 | biak
# Processing Record 34 of Set 6 | proletarsk
# Processing Record 35 of Set 6 | svirstroy
# Processing Record 36 of Set 6 | nueva imperial
# Processing Record 37 of Set 6 | sungai kolok
# City not found. Skipping...
# Processing Record 38 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 6 | guarapari
# Processing Record 40 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 6 | bilibino
# Processing Record 42 of Set 6 | marystown
# Processing Record 43 of Set 6 | dhidhdhoo
# Processing Record 44 of Set 6 | isangel
# Processing Record 45 of Set 6 | abu kamal
# Processing Record 46 of Set 6 | pingliang
# Processing Record 47 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 6 | pismo beach
# Processing Record 49 of Set 6 | lebu
# Processing Record 0 of Set 7 | itaituba
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | waitati
# Processing Record 3 of Set 7 | morro bay
# Processing Record 4 of Set 7 | mala
# Processing Record 5 of Set 7 | kristiinankaupunki
# Processing Record 6 of Set 7 | abu dhabi
# Processing Record 7 of Set 7 | harper
# Processing Record 8 of Set 7 | brainerd
# Processing Record 9 of Set 7 | batagay
# Processing Record 10 of Set 7 | san quintin
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | eyl
# Processing Record 13 of Set 7 | kurilsk
# Processing Record 14 of Set 7 | campiglia marittima
# Processing Record 15 of Set 7 | pavino
# Processing Record 16 of Set 7 | arraial do cabo
# Processing Record 17 of Set 7 | emerald
# Processing Record 18 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 7 | ancud
# Processing Record 20 of Set 7 | kizhinga
# Processing Record 21 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 7 | tochigi
# Processing Record 23 of Set 7 | saskylakh
# Processing Record 24 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 26 of Set 7 | sheopur
# Processing Record 27 of Set 7 | inirida
# Processing Record 28 of Set 7 | najran
# Processing Record 29 of Set 7 | alice springs
# Processing Record 30 of Set 7 | lakota
# Processing Record 31 of Set 7 | anshun
# Processing Record 32 of Set 7 | camacha
# Processing Record 33 of Set 7 | buala
# Processing Record 34 of Set 7 | kieta
# Processing Record 35 of Set 7 | cidreira
# Processing Record 36 of Set 7 | kavieng
# Processing Record 37 of Set 7 | bireun
# Processing Record 38 of Set 7 | sioux lookout
# Processing Record 39 of Set 7 | namatanai
# Processing Record 40 of Set 7 | ilinskiy
# Processing Record 41 of Set 7 | kinsale
# Processing Record 42 of Set 7 | pierre
# Processing Record 43 of Set 7 | sorland
# Processing Record 44 of Set 7 | chancay
# Processing Record 45 of Set 7 | bilma
# Processing Record 46 of Set 7 | maua
# Processing Record 47 of Set 7 | tonantins
# Processing Record 48 of Set 7 | gorontalo
# Processing Record 49 of Set 7 | tevriz
# Processing Record 0 of Set 8 | gualeguaychu
# Processing Record 1 of Set 8 | amazar
# Processing Record 2 of Set 8 | miles city
# Processing Record 3 of Set 8 | saint-augustin
# Processing Record 4 of Set 8 | hobyo
# Processing Record 5 of Set 8 | tura
# Processing Record 6 of Set 8 | khani
# Processing Record 7 of Set 8 | zhaoyang
# Processing Record 8 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 8 | skalnyy
# City not found. Skipping...
# Processing Record 10 of Set 8 | gladstone
# Processing Record 11 of Set 8 | ankang
# Processing Record 12 of Set 8 | minab
# Processing Record 13 of Set 8 | fairbanks
# Processing Record 14 of Set 8 | chumikan
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | ponta do sol
# Processing Record 17 of Set 8 | male
# Processing Record 18 of Set 8 | chapleau
# Processing Record 19 of Set 8 | shelburne
# Processing Record 20 of Set 8 | hvide sande
# Processing Record 21 of Set 8 | khasan
# Processing Record 22 of Set 8 | khorinsk
# Processing Record 23 of Set 8 | port hardy
# Processing Record 24 of Set 8 | mount isa
# Processing Record 25 of Set 8 | fortuna
# Processing Record 26 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 27 of Set 8 | iberia
# Processing Record 28 of Set 8 | kirakira
# Processing Record 29 of Set 8 | biu
# Processing Record 30 of Set 8 | atikokan
# Processing Record 31 of Set 8 | dayong
# Processing Record 32 of Set 8 | rabat
# Processing Record 33 of Set 8 | kanniyakumari
# Processing Record 34 of Set 8 | coquimbo
# Processing Record 35 of Set 8 | yenagoa
# Processing Record 36 of Set 8 | kaitangata
# Processing Record 37 of Set 8 | pemba
# Processing Record 38 of Set 8 | samana
# Processing Record 39 of Set 8 | esso
# Processing Record 40 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 41 of Set 8 | ponta delgada
# Processing Record 42 of Set 8 | dunedin
# Processing Record 43 of Set 8 | nassjo
# Processing Record 44 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 8 | iquique
# Processing Record 46 of Set 8 | durango
# Processing Record 47 of Set 8 | chulym
# Processing Record 48 of Set 8 | poronaysk
# Processing Record 49 of Set 8 | luanda
# Processing Record 0 of Set 9 | colac
# Processing Record 1 of Set 9 | totness
# Processing Record 2 of Set 9 | pithoragarh
# Processing Record 3 of Set 9 | vila velha
# Processing Record 4 of Set 9 | nongstoin
# Processing Record 5 of Set 9 | nago
# Processing Record 6 of Set 9 | ravar
# Processing Record 7 of Set 9 | garachine
# Processing Record 8 of Set 9 | xuanzhou
# Processing Record 9 of Set 9 | touros
# Processing Record 10 of Set 9 | sao joao da barra
# Processing Record 11 of Set 9 | lata
# Processing Record 12 of Set 9 | kavaratti
# Processing Record 13 of Set 9 | jaisalmer
# Processing Record 14 of Set 9 | riviere-au-renard
# Processing Record 15 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 9 | batsfjord
# Processing Record 17 of Set 9 | vostok
# Processing Record 18 of Set 9 | bakchar
# Processing Record 19 of Set 9 | nautla
# Processing Record 20 of Set 9 | havoysund
# Processing Record 21 of Set 9 | port moresby
# Processing Record 22 of Set 9 | springfield
# Processing Record 23 of Set 9 | bandundu
# Processing Record 24 of Set 9 | teguldet
# Processing Record 25 of Set 9 | tabou
# Processing Record 26 of Set 9 | noumea
# Processing Record 27 of Set 9 | princeton
# Processing Record 28 of Set 9 | roma
# Processing Record 29 of Set 9 | les cayes
# Processing Record 30 of Set 9 | herat
# Processing Record 31 of Set 9 | brod
# Processing Record 32 of Set 9 | dunda
# Processing Record 33 of Set 9 | camana
# Processing Record 34 of Set 9 | kawhia
# Processing Record 35 of Set 9 | mega
# Processing Record 36 of Set 9 | hambantota
# Processing Record 37 of Set 9 | sol-iletsk
# Processing Record 38 of Set 9 | port said
# Processing Record 39 of Set 9 | melfi
# Processing Record 40 of Set 9 | san jeronimo
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | amapa
# Processing Record 43 of Set 9 | chicontepec
# Processing Record 44 of Set 9 | staunton
# Processing Record 45 of Set 9 | doka
# Processing Record 46 of Set 9 | saiha
# Processing Record 47 of Set 9 | nuuk
# Processing Record 48 of Set 9 | ambulu
# Processing Record 49 of Set 9 | lavrentiya
# Processing Record 0 of Set 10 | faya
# Processing Record 1 of Set 10 | okahandja
# Processing Record 2 of Set 10 | margate
# Processing Record 3 of Set 10 | usman
# Processing Record 4 of Set 10 | staroye drozhzhanoye
# Processing Record 5 of Set 10 | burgeo
# Processing Record 6 of Set 10 | zhashkiv
# Processing Record 7 of Set 10 | merauke
# Processing Record 8 of Set 10 | tarko-sale
# Processing Record 9 of Set 10 | crib point
# Processing Record 10 of Set 10 | ebeltoft
# Processing Record 11 of Set 10 | axim
# Processing Record 12 of Set 10 | rawson
# Processing Record 13 of Set 10 | panguna
# Processing Record 14 of Set 10 | lufilufi
# Processing Record 15 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 10 | arlit
# Processing Record 17 of Set 10 | oxapampa
# Processing Record 18 of Set 10 | nabire
# Processing Record 19 of Set 10 | machhiwara
# Processing Record 20 of Set 10 | kaita
# Processing Record 21 of Set 10 | mehamn
# Processing Record 22 of Set 10 | passagem franca
# Processing Record 23 of Set 10 | sechelt
# Processing Record 24 of Set 10 | takoradi
# Processing Record 25 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 26 of Set 10 | bulancak
# Processing Record 27 of Set 10 | itarema
# Processing Record 28 of Set 10 | san lazaro
# Processing Record 29 of Set 10 | totskoye
# Processing Record 30 of Set 10 | mkushi
# Processing Record 31 of Set 10 | langenburg
# Processing Record 32 of Set 10 | avera
# Processing Record 33 of Set 10 | ereymentau
# Processing Record 34 of Set 10 | marrakesh
# Processing Record 35 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 10 | uniontown
# Processing Record 37 of Set 10 | dakar
# Processing Record 38 of Set 10 | pedasi
# Processing Record 39 of Set 10 | florianopolis
# Processing Record 40 of Set 10 | santa rosa
# Processing Record 41 of Set 10 | camargo
# Processing Record 42 of Set 10 | nurlat
# Processing Record 43 of Set 10 | moyale
# Processing Record 44 of Set 10 | dali
# Processing Record 45 of Set 10 | luz
# Processing Record 46 of Set 10 | necochea
# Processing Record 47 of Set 10 | krasnokamensk
# Processing Record 48 of Set 10 | nelson bay
# Processing Record 49 of Set 10 | zalantun
# Processing Record 0 of Set 11 | cockburn town
# Processing Record 1 of Set 11 | broken hill
# Processing Record 2 of Set 11 | murud
# Processing Record 3 of Set 11 | yuzhno-kurilsk
# Processing Record 4 of Set 11 | belyy yar
# Processing Record 5 of Set 11 | sorong
# Processing Record 6 of Set 11 | srednekolymsk
# Processing Record 7 of Set 11 | dullewala
# Processing Record 8 of Set 11 | urumqi
# Processing Record 9 of Set 11 | ola
# Processing Record 10 of Set 11 | toguchin
# Processing Record 11 of Set 11 | sinnai
# Processing Record 12 of Set 11 | quatre cocos
# Processing Record 13 of Set 11 | umm lajj
# Processing Record 14 of Set 11 | bay roberts
# Processing Record 15 of Set 11 | charters towers
# Processing Record 16 of Set 11 | lydenburg
# Processing Record 17 of Set 11 | andrelandia
# Processing Record 18 of Set 11 | agadir
# Processing Record 19 of Set 11 | san luis rio colorado
# Processing Record 20 of Set 11 | buin
# Processing Record 21 of Set 11 | amursk
# Processing Record 22 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 23 of Set 11 | ushtobe
# Processing Record 24 of Set 11 | baixo guandu
# Processing Record 25 of Set 11 | shache
# Processing Record 26 of Set 11 | almonte
# Processing Record 27 of Set 11 | paratinga
# Processing Record 28 of Set 11 | logan
# Processing Record 29 of Set 11 | brazzaville
# Processing Record 30 of Set 11 | virginia beach
# Processing Record 31 of Set 11 | sandy bay
# Processing Record 32 of Set 11 | abha
# Processing Record 33 of Set 11 | golden rock
# City not found. Skipping...
# Processing Record 34 of Set 11 | banjar
# Processing Record 35 of Set 11 | lakes entrance
# Processing Record 36 of Set 11 | nevelsk
# Processing Record 37 of Set 11 | akdagmadeni
# Processing Record 38 of Set 11 | samarai
# Processing Record 39 of Set 11 | channel-port aux basques
# Processing Record 40 of Set 11 | olinda
# Processing Record 41 of Set 11 | chesma
# Processing Record 42 of Set 11 | atar
# Processing Record 43 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 11 | tadine
# Processing Record 45 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 11 | aklavik
# Processing Record 47 of Set 11 | hofn
# Processing Record 48 of Set 11 | colares
# Processing Record 49 of Set 11 | healesville
# Processing Record 0 of Set 12 | saint-georges
# Processing Record 1 of Set 12 | lixourion
# Processing Record 2 of Set 12 | seymchan
# Processing Record 3 of Set 12 | grand gaube
# Processing Record 4 of Set 12 | sladkovo
# Processing Record 5 of Set 12 | nueve de julio
# Processing Record 6 of Set 12 | flinders
# Processing Record 7 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 12 | genhe
# Processing Record 9 of Set 12 | bulolo
# Processing Record 10 of Set 12 | kasongo-lunda
# Processing Record 11 of Set 12 | zyryanka
# Processing Record 12 of Set 12 | jumla
# Processing Record 13 of Set 12 | sierra vista
# Processing Record 14 of Set 12 | komsomolskiy
# Processing Record 15 of Set 12 | portland
# Processing Record 16 of Set 12 | kungurtug
# Processing Record 17 of Set 12 | gat
# Processing Record 18 of Set 12 | dauphin
# Processing Record 19 of Set 12 | senador jose porfirio
# Processing Record 20 of Set 12 | meiningen
# Processing Record 21 of Set 12 | san policarpo
# Processing Record 22 of Set 12 | zhigansk
# Processing Record 23 of Set 12 | puerto penasco
# Processing Record 24 of Set 12 | wakkanai
# Processing Record 25 of Set 12 | methoni
# Processing Record 26 of Set 12 | vysokogornyy
# Processing Record 27 of Set 12 | pahrump
# Processing Record 28 of Set 12 | tautira
# Processing Record 29 of Set 12 | kalmunai
# Processing Record 30 of Set 12 | winnemucca
# Processing Record 31 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 32 of Set 12 | porbandar
# Processing Record 33 of Set 12 | ler
# Processing Record 34 of Set 12 | te anau
# Processing Record 35 of Set 12 | baykit
# Processing Record 36 of Set 12 | las matas de farfan
# Processing Record 37 of Set 12 | gimli
# Processing Record 38 of Set 12 | lady frere
# Processing Record 39 of Set 12 | ostrovnoy
# Processing Record 40 of Set 12 | remanso
# Processing Record 41 of Set 12 | vyazemskiy
# Processing Record 42 of Set 12 | ouegoa
# Processing Record 43 of Set 12 | bac lieu
# Processing Record 44 of Set 12 | bodden town
# Processing Record 45 of Set 12 | khiv
# Processing Record 46 of Set 12 | ninh binh
# Processing Record 47 of Set 12 | tariba
# Processing Record 48 of Set 12 | anloga
# Processing Record 49 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 0 of Set 13 | sabla
# Processing Record 1 of Set 13 | prince rupert
# Processing Record 2 of Set 13 | ranong
# Processing Record 3 of Set 13 | mut
# Processing Record 4 of Set 13 | bassano
# City not found. Skipping...
# Processing Record 5 of Set 13 | yerofey pavlovich
# Processing Record 6 of Set 13 | yulara
# Processing Record 7 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 13 | barabash
# Processing Record 9 of Set 13 | jiuquan
# Processing Record 10 of Set 13 | vestmannaeyjar
# Processing Record 11 of Set 13 | koungheul
# Processing Record 12 of Set 13 | padang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.09,
#   'Humidity': 81,
#   'Cloudiness': 58,
#   'Wind Speed': 14.07,
#   'Country': 'PF',
#   'Date': 1667554019},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 49.91,
#   'Humidity': 71,
#   'Cloudiness': 34,
#   'Wind Speed': 27.34,
#   'Country': 'NZ',
#   'Date': 1667554020},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 63.77,
#   'Humidity': 52,
#   'Cloudiness': 59,
#   'Wind Speed': 14.74,
#   'Country': 'AU',
#   'Date': 1667554022},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 51.96,
#   'Humidity': 81,
#   'Cloudiness': 73,
#   'Wind Speed': 5.14,
#   'Country': 'AU',
#   'Date': 1667554023},
#  {'City': 'kabinda',
#   'Lat': -6.1333,
#   'Lng': 24.4833,
#   'Max Temp': 80.22,
#   'Humidity': 54,
#   'Cloudiness': 90,
#   'Wind Speed': 3.69,
#   'Country': 'CD',
#   'Date': 1667554026},
#  {'City': 'luorong',
#   'Lat': 24.4058,
#   'Lng': 109.6086,
#   'Max Temp': 75.65,
#   'Humidity': 36,
#   'Cloudiness': 89,
#   'Wind Speed': 12.64,
#   'Country': 'CN',
#   'Date': 1667554027},
#  {'City': 'sangar',
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp': -4.36,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 1.1,
#   'Country': 'RU',
#   'Date': 1667554028},
#  {'City': 'severo-kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 38.95,
#   'Humidity': 74,
#   'Cloudiness': 31,
#   'Wind Speed': 9.95,
#   'Country': 'RU',
#   'Date': 1667554029},
#  {'City': 'nyahururu',
#   'Lat': 0.0421,
#   'Lng': 36.3673,
#   'Max Temp': 59.76,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Country': 'KE',
#   'Date': 1667554030},
#  {'City': 'pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -16.56,
#   'Humidity': 98,
#   'Cloudiness': 32,
#   'Wind Speed': 6.15,
#   'Country': 'RU',
#   'Date': 1667554032},
#  {'City': 'sao manuel',
#   'Lat': -22.7311,
#   'Lng': -48.5706,
#   'Max Temp': 50.74,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 10.38,
#   'Country': 'BR',
#   'Date': 1667554034},
#  {'City': 'irricana',
#   'Lat': 51.3237,
#   'Lng': -113.6048,
#   'Max Temp': 33.78,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 6.46,
#   'Country': 'CA',
#   'Date': 1667554035},
#  {'City': 'vargem grande',
#   'Lat': -3.5431,
#   'Lng': -43.9158,
#   'Max Temp': 73.67,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Country': 'BR',
#   'Date': 1667554036},
#  {'City': 'rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 70.12,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 15.73,
#   'Country': 'PF',
#   'Date': 1667553793},
#  {'City': 'adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 74.37,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 10.25,
#   'Country': 'MR',
#   'Date': 1667554037},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 72.9,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 25.3,
#   'Country': 'AU',
#   'Date': 1667554038},
#  {'City': 'nacala',
#   'Lat': -14.5428,
#   'Lng': 40.6728,
#   'Max Temp': 87.12,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'MZ',
#   'Date': 1667554039},
#  {'City': 'mar del plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 56.88,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 7,
#   'Country': 'AR',
#   'Date': 1667554030},
#  {'City': 'abdanan',
#   'Lat': 32.9926,
#   'Lng': 47.4198,
#   'Max Temp': 68.68,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 4.94,
#   'Country': 'IR',
#   'Date': 1667554042},
#  {'City': 'verkhoyansk',
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp': -1.66,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.04,
#   'Country': 'RU',
#   'Date': 1667554043},
#  {'City': 'hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 55.26,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': 1667554044},
#  {'City': 'qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 16.65,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Country': 'GL',
#   'Date': 1667554045},
#  {'City': 'strezhevoy',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 30.56,
#   'Humidity': 86,
#   'Cloudiness': 68,
#   'Wind Speed': 5.17,
#   'Country': 'RU',
#   'Date': 1667553789},
#  {'City': 'airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 66.24,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Country': 'TL',
#   'Date': 1667554046},
#  {'City': 'mount gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 52.99,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 3.74,
#   'Country': 'AU',
#   'Date': 1667554047},
#  {'City': 'clyde river',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 14.23,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': 1667554048},
#  {'City': 'cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 75.24,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'GF',
#   'Date': 1667554050},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 58.59,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': 1667554051},
#  {'City': 'nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 17.67,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1667554052},
#  {'City': 'tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32.16,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 14.2,
#   'Country': 'GL',
#   'Date': 1667554053},
#  {'City': 'provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 14.92,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 7.52,
#   'Country': 'RU',
#   'Date': 1667554054},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.36,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'TO',
#   'Date': 1667554055},
#  {'City': 'klichka',
#   'Lat': 50.4457,
#   'Lng': 117.996,
#   'Max Temp': 23.59,
#   'Humidity': 58,
#   'Cloudiness': 84,
#   'Wind Speed': 5.48,
#   'Country': 'RU',
#   'Date': 1667554056},
#  {'City': 'los llanos de aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 71.35,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'ES',
#   'Date': 1667554057},
#  {'City': 'tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 48.04,
#   'Humidity': 79,
#   'Cloudiness': 64,
#   'Wind Speed': 11.65,
#   'Country': 'NZ',
#   'Date': 1667554058},
#  {'City': 'bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 81.16,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 6.93,
#   'Country': 'ID',
#   'Date': 1667554060},
#  {'City': 'husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 37.81,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Country': 'IS',
#   'Date': 1667554061},
#  {'City': 'mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 45.73,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 9.19,
#   'Country': 'NZ',
#   'Date': 1667554062},
#  {'City': 'grand island',
#   'Lat': 40.925,
#   'Lng': -98.342,
#   'Max Temp': 35.55,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Date': 1667554062},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 69.78,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'PT',
#   'Date': 1667554064},
#  {'City': 'dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 80.67,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Country': 'PH',
#   'Date': 1667554065},
#  {'City': 'taguatinga',
#   'Lat': -12.3857,
#   'Lng': -46.5711,
#   'Max Temp': 69.17,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'BR',
#   'Date': 1667554066},
#  {'City': 'lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 67.69,
#   'Humidity': 91,
#   'Cloudiness': 2,
#   'Wind Speed': 22.08,
#   'Country': 'PT',
#   'Date': 1667554067},
#  {'City': 'butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.33,
#   'Humidity': 71,
#   'Cloudiness': 9,
#   'Wind Speed': 12.66,
#   'Country': 'KI',
#   'Date': 1667554068},
#  {'City': 'tyukhtet',
#   'Lat': 56.5389,
#   'Lng': 89.3011,
#   'Max Temp': 33.24,
#   'Humidity': 74,
#   'Cloudiness': 80,
#   'Wind Speed': 3.36,
#   'Country': 'RU',
#   'Date': 1667554069},
#  {'City': 'lebedyan',
#   'Lat': 53.0194,
#   'Lng': 39.1664,
#   'Max Temp': 36.59,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3.42,
#   'Country': 'RU',
#   'Date': 1667554070},
#  {'City': 'tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 70.86,
#   'Humidity': 35,
#   'Cloudiness': 4,
#   'Wind Speed': 1.86,
#   'Country': 'MA',
#   'Date': 1667554071},
#  {'City': 'labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 85.6,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'ID',
#   'Date': 1667554072},
#  {'City': 'college',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 12.15,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1667554072},
#  {'City': 'sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 80.33,
#   'Humidity': 61,
#   'Cloudiness': 84,
#   'Wind Speed': 9.24,
#   'Country': 'MG',
#   'Date': 1667554073},
#  {'City': 'phan thiet',
#   'Lat': 10.9333,
#   'Lng': 108.1,
#   'Max Temp': 81.46,
#   'Humidity': 76,
#   'Cloudiness': 37,
#   'Wind Speed': 17.16,
#   'Country': 'VN',
#   'Date': 1667553839},
#  {'City': 'dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 21.74,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Country': 'RU',
#   'Date': 1667554075},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 70.18,
#   'Humidity': 78,
#   'Cloudiness': 66,
#   'Wind Speed': 5.99,
#   'Country': 'ZA',
#   'Date': 1667554076},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 82.36,
#   'Humidity': 72,
#   'Cloudiness': 35,
#   'Wind Speed': 13.73,
#   'Country': 'MV',
#   'Date': 1667554078},
#  {'City': 'darhan',
#   'Lat': 49.4867,
#   'Lng': 105.9228,
#   'Max Temp': 31.89,
#   'Humidity': 48,
#   'Cloudiness': 22,
#   'Wind Speed': 5.39,
#   'Country': 'MN',
#   'Date': 1667554079},
#  {'City': 'hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 59.4,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 19.71,
#   'Country': 'JP',
#   'Date': 1667554080},
#  {'City': 'bemidji',
#   'Lat': 47.4736,
#   'Lng': -94.8803,
#   'Max Temp': 32.05,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': 1667554081},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 11.93,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Date': 1667554082},
#  {'City': 'constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 49.08,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Country': 'CL',
#   'Date': 1667553957},
#  {'City': 'norman wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 3.24,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'CA',
#   'Date': 1667554084},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 68.92,
#   'Humidity': 63,
#   'Cloudiness': 10,
#   'Wind Speed': 8.21,
#   'Country': 'NA',
#   'Date': 1667554086},
#  {'City': 'half moon bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 52.99,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': 1667554042},
#  {'City': 'bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 50.94,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1667554088},
#  {'City': 'mafinga',
#   'Lat': -7.25,
#   'Lng': 35.0667,
#   'Max Temp': 88.75,
#   'Humidity': 27,
#   'Cloudiness': 69,
#   'Wind Speed': 5.93,
#   'Country': 'TZ',
#   'Date': 1667554078},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 47.86,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 27.63,
#   'Country': 'AR',
#   'Date': 1667554090},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 57.31,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'CL',
#   'Date': 1667553946},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 19.56,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 15.01,
#   'Country': 'CA',
#   'Date': 1667554091},
#  {'City': 'comodoro rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 60.06,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 3.53,
#   'Country': 'AR',
#   'Date': 1667554092},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 68.4,
#   'Humidity': 75,
#   'Cloudiness': 77,
#   'Wind Speed': 12.48,
#   'Country': 'ZA',
#   'Date': 1667554093},
#  {'City': 'susuman',
#   'Lat': 62.7833,
#   'Lng': 148.1667,
#   'Max Temp': 0.14,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.83,
#   'Country': 'RU',
#   'Date': 1667554094},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.25,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'CK',
#   'Date': 1667554095},
#  {'City': 'indramayu',
#   'Lat': -6.3264,
#   'Lng': 108.32,
#   'Max Temp': 85.15,
#   'Humidity': 67,
#   'Cloudiness': 99,
#   'Wind Speed': 9.86,
#   'Country': 'ID',
#   'Date': 1667554096},
#  {'City': 'angol',
#   'Lat': -37.8,
#   'Lng': -72.7167,
#   'Max Temp': 54.75,
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 1.36,
#   'Country': 'CL',
#   'Date': 1667554097},
#  {'City': 'kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 80.73,
#   'Humidity': 15,
#   'Cloudiness': 71,
#   'Wind Speed': 21.77,
#   'Country': 'ML',
#   'Date': 1667554098},
#  {'City': 'nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 30.09,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 3.06,
#   'Country': 'RU',
#   'Date': 1667554100},
#  {'City': 'chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 58.87,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 9.08,
#   'Country': 'UY',
#   'Date': 1667554101},
#  {'City': 'salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 86.09,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'OM',
#   'Date': 1667554103},
#  {'City': 'pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 2.62,
#   'Humidity': 81,
#   'Cloudiness': 9,
#   'Wind Speed': 11.14,
#   'Country': 'CA',
#   'Date': 1667554105},
#  {'City': 'tenenkou',
#   'Lat': 14.4572,
#   'Lng': -4.9169,
#   'Max Temp': 85.17,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 10.96,
#   'Country': 'ML',
#   'Date': 1667554107},
#  {'City': 'castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 44.96,
#   'Humidity': 95,
#   'Cloudiness': 91,
#   'Wind Speed': 4.9,
#   'Country': 'BR',
#   'Date': 1667554108},
#  {'City': 'saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 73.45,
#   'Humidity': 77,
#   'Cloudiness': 27,
#   'Wind Speed': 10.04,
#   'Country': 'ZA',
#   'Date': 1667554109},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 66.56,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 10.83,
#   'Country': 'EC',
#   'Date': 1667554110},
#  {'City': 'maunatlala',
#   'Lat': -22.597,
#   'Lng': 27.6301,
#   'Max Temp': 85.12,
#   'Humidity': 42,
#   'Cloudiness': 100,
#   'Wind Speed': 11.56,
#   'Country': 'BW',
#   'Date': 1667554111},
#  {'City': 'haapiti',
#   'Lat': -17.5667,
#   'Lng': -149.8667,
#   'Max Temp': 77.72,
#   'Humidity': 78,
#   'Cloudiness': 98,
#   'Wind Speed': 19.66,
#   'Country': 'PF',
#   'Date': 1667554112},
#  {'City': 'seoul',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 45.84,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'KR',
#   'Date': 1667554066},
#  {'City': 'hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 74.62,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1667554114},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 54.91,
#   'Humidity': 63,
#   'Cloudiness': 84,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': 1667554114},
#  {'City': 'east london',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 76.14,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'ZA',
#   'Date': 1667554115},
#  {'City': 'palu',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 81.75,
#   'Humidity': 90,
#   'Cloudiness': 44,
#   'Wind Speed': 1.83,
#   'Country': 'ID',
#   'Date': 1667554116},
#  {'City': 'karratha',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 87.13,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 9.57,
#   'Country': 'AU',
#   'Date': 1667554117},
#  {'City': 'kathmandu',
#   'Lat': 27.7167,
#   'Lng': 85.3167,
#   'Max Temp': 73.62,
#   'Humidity': 43,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'NP',
#   'Date': 1667554077},
#  {'City': 'gazli',
#   'Lat': 40.1333,
#   'Lng': 63.45,
#   'Max Temp': 66.25,
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind Speed': 13.11,
#   'Country': 'UZ',
#   'Date': 1667554119},
#  {'City': 'esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 64.11,
#   'Humidity': 80,
#   'Cloudiness': 96,
#   'Wind Speed': 18.81,
#   'Country': 'AU',
#   'Date': 1667554120},
#  {'City': 'ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 96.67,
#   'Humidity': 23,
#   'Cloudiness': 6,
#   'Wind Speed': 2.04,
#   'Country': 'MG',
#   'Date': 1667554122},
#  {'City': 'olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 40.59,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 11.36,
#   'Country': 'IS',
#   'Date': 1667554123},
#  {'City': 'omsukchan',
#   'Lat': 62.5333,
#   'Lng': 155.8,
#   'Max Temp': 6.26,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.39,
#   'Country': 'RU',
#   'Date': 1667554124},
#  {'City': 'vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 41.11,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 16.37,
#   'Country': 'NO',
#   'Date': 1667554125},
#  {'City': 'shakawe',
#   'Lat': -18.3667,
#   'Lng': 21.85,
#   'Max Temp': 87.84,
#   'Humidity': 37,
#   'Cloudiness': 56,
#   'Wind Speed': 6.4,
#   'Country': 'BW',
#   'Date': 1667554126},
#  {'City': 'sistranda',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 53.56,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'NO',
#   'Date': 1667554127},
#  {'City': 'hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 34.9,
#   'Humidity': 47,
#   'Cloudiness': 48,
#   'Wind Speed': 3.15,
#   'Country': 'MN',
#   'Date': 1667554129},
#  {'City': 'souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 82.78,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'MU',
#   'Date': 1667554130},
#  {'City': 'khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -7.19,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.81,
#   'Country': 'RU',
#   'Date': 1667554131},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 82.09,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 18.41,
#   'Country': 'ZA',
#   'Date': 1667554020},
#  {'City': 'peleduy',
#   'Lat': 59.6289,
#   'Lng': 112.7406,
#   'Max Temp': 11.16,
#   'Humidity': 87,
#   'Cloudiness': 52,
#   'Wind Speed': 4.88,
#   'Country': 'RU',
#   'Date': 1667554134},
#  {'City': 'victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 75.38,
#   'Humidity': 85,
#   'Cloudiness': 42,
#   'Wind Speed': 13,
#   'Country': 'HK',
#   'Date': 1667553988},
#  {'City': 'rio grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 57.42,
#   'Humidity': 68,
#   'Cloudiness': 7,
#   'Wind Speed': 10.71,
#   'Country': 'BR',
#   'Date': 1667554135},
#  {'City': 'plettenberg bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 70.48,
#   'Humidity': 72,
#   'Cloudiness': 36,
#   'Wind Speed': 9.01,
#   'Country': 'ZA',
#   'Date': 1667554136},
#  {'City': 'makakilo city',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 78.01,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': 1667554137},
#  {'City': 'dubbo',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 60.46,
#   'Humidity': 71,
#   'Cloudiness': 97,
#   'Wind Speed': 6.26,
#   'Country': 'AU',
#   'Date': 1667554138},
#  {'City': 'lavumisa',
#   'Lat': -27.31,
#   'Lng': 31.892,
#   'Max Temp': 87.1,
#   'Humidity': 47,
#   'Cloudiness': 95,
#   'Wind Speed': 7.81,
#   'Country': 'SZ',
#   'Date': 1667554139},
#  {'City': 'paramonga',
#   'Lat': -10.6667,
#   'Lng': -77.8333,
#   'Max Temp': 61.25,
#   'Humidity': 90,
#   'Cloudiness': 55,
#   'Wind Speed': 6.08,
#   'Country': 'PE',
#   'Date': 1667554140},
#  {'City': 'knysna',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 74.62,
#   'Humidity': 63,
#   'Cloudiness': 49,
#   'Wind Speed': 7.76,
#   'Country': 'ZA',
#   'Date': 1667554142},
#  {'City': 'fonte boa',
#   'Lat': -2.4959,
#   'Lng': -66.2662,
#   'Max Temp': 71.08,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'BR',
#   'Date': 1667554143},
#  {'City': 'moche',
#   'Lat': -8.1711,
#   'Lng': -79.0092,
#   'Max Temp': 60.98,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'PE',
#   'Date': 1667554144},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 4.64,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 10.13,
#   'Country': 'CA',
#   'Date': 1667554145},
#  {'City': 'taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 57.96,
#   'Humidity': 81,
#   'Cloudiness': 58,
#   'Wind Speed': 1.48,
#   'Country': 'CL',
#   'Date': 1667554146},
#  {'City': 'odessa',
#   'Lat': 46.4775,
#   'Lng': 30.7326,
#   'Max Temp': 52.38,
#   'Humidity': 61,
#   'Cloudiness': 25,
#   'Wind Speed': 1.25,
#   'Country': 'UA',
#   'Date': 1667554147},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 51.31,
#   'Humidity': 76,
#   'Cloudiness': 2,
#   'Wind Speed': 2.48,
#   'Country': 'US',
#   'Date': 1667554080},
#  {'City': 'norton shores',
#   'Lat': 43.1689,
#   'Lng': -86.2639,
#   'Max Temp': 64.42,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 21,
#   'Country': 'US',
#   'Date': 1667554150},
#  {'City': 'kailua',
#   'Lat': 21.4022,
#   'Lng': -157.7394,
#   'Max Temp': 79.48,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': 1667554151},
#  {'City': 'verkhniye achaluki',
#   'Lat': 43.3469,
#   'Lng': 44.6975,
#   'Max Temp': 48.65,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Date': 1667554152},
#  {'City': 'valparai',
#   'Lat': 10.3667,
#   'Lng': 76.9667,
#   'Max Temp': 77.67,
#   'Humidity': 84,
#   'Cloudiness': 87,
#   'Wind Speed': 2.55,
#   'Country': 'IN',
#   'Date': 1667554153},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 28.42,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'GL',
#   'Date': 1667554154},
#  {'City': 'pinotepa nacional',
#   'Lat': 16.3167,
#   'Lng': -98.0167,
#   'Max Temp': 75.88,
#   'Humidity': 87,
#   'Cloudiness': 93,
#   'Wind Speed': 1.97,
#   'Country': 'MX',
#   'Date': 1667554155},
#  {'City': 'abu samrah',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 70.05,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 4.92,
#   'Country': 'SY',
#   'Date': 1667554156},
#  {'City': 'valparaiso',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 55.04,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': 1667554157},
#  {'City': 'chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -18.51,
#   'Humidity': 93,
#   'Cloudiness': 39,
#   'Wind Speed': 3.24,
#   'Country': 'RU',
#   'Date': 1667554159},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 61.02,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'PE',
#   'Date': 1667554159},
#  {'City': 'saraland',
#   'Lat': 30.8207,
#   'Lng': -88.0706,
#   'Max Temp': 72.32,
#   'Humidity': 90,
#   'Cloudiness': 2,
#   'Wind Speed': 4.25,
#   'Country': 'US',
#   'Date': 1667554161},
#  {'City': 'pangody',
#   'Lat': 65.85,
#   'Lng': 74.4859,
#   'Max Temp': 14.02,
#   'Humidity': 98,
#   'Cloudiness': 71,
#   'Wind Speed': 3.71,
#   'Country': 'RU',
#   'Date': 1667554161},
#  {'City': 'kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 79.12,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': 1667554162},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 49.01,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1667554163},
#  {'City': 'vydrino',
#   'Lat': 51.485,
#   'Lng': 104.8461,
#   'Max Temp': 36.5,
#   'Humidity': 68,
#   'Cloudiness': 61,
#   'Wind Speed': 1.39,
#   'Country': 'RU',
#   'Date': 1667554164},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 90.16,
#   'Humidity': 28,
#   'Cloudiness': 5,
#   'Wind Speed': 2.51,
#   'Country': 'OM',
#   'Date': 1667554165},
#  {'City': 'pittsfield',
#   'Lat': 42.4501,
#   'Lng': -73.2454,
#   'Max Temp': 50.2,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1667554166},
#  {'City': 'lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 82.62,
#   'Humidity': 76,
#   'Cloudiness': 86,
#   'Wind Speed': 2.26,
#   'Country': 'PG',
#   'Date': 1667554167},
#  {'City': 'kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 79.88,
#   'Humidity': 45,
#   'Cloudiness': 97,
#   'Wind Speed': 14.76,
#   'Country': 'ZA',
#   'Date': 1667554168},
#  {'City': 'caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 70.72,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 16.69,
#   'Country': 'BR',
#   'Date': 1667554169},
#  {'City': 'cape town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 75.61,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ZA',
#   'Date': 1667554170},
#  {'City': 'george',
#   'Lat': -33.963,
#   'Lng': 22.4617,
#   'Max Temp': 69.35,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Date': 1667554171},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 84.88,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'MY',
#   'Date': 1667553920},
#  {'City': 'geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 66.67,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 20.09,
#   'Country': 'AU',
#   'Date': 1667554172},
#  {'City': 'broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 50.59,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': 1667554173},
#  {'City': 'bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 82.45,
#   'Humidity': 66,
#   'Cloudiness': 42,
#   'Wind Speed': 9.48,
#   'Country': 'SO',
#   'Date': 1667554175},
#  {'City': 'xichang',
#   'Lat': 27.8964,
#   'Lng': 102.2634,
#   'Max Temp': 63.79,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'CN',
#   'Date': 1667554176},
#  {'City': 'barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 17.62,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1667554177},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 68.29,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 14.2,
#   'Country': 'ZA',
#   'Date': 1667554178},
#  {'City': 'killybegs',
#   'Lat': 54.6333,
#   'Lng': -8.45,
#   'Max Temp': 49.71,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.25,
#   'Country': 'IE',
#   'Date': 1667554179},
#  {'City': 'saint george',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 38.95,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': 1667554180},
#  {'City': 'nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 35.78,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 10.45,
#   'Country': 'GL',
#   'Date': 1667554181},
#  {'City': 'richards bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 81.46,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'ZA',
#   'Date': 1667554182},
#  {'City': 'alta floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 71.01,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3.33,
#   'Country': 'BR',
#   'Date': 1667554183},
#  {'City': 'xocali',
#   'Lat': 39.913,
#   'Lng': 46.7903,
#   'Max Temp': 60.21,
#   'Humidity': 38,
#   'Cloudiness': 56,
#   'Wind Speed': 6.85,
#   'Country': 'AZ',
#   'Date': 1667554184},
#  {'City': 'kazanskoye',
#   'Lat': 55.6448,
#   'Lng': 69.235,
#   'Max Temp': 37.06,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'RU',
#   'Date': 1667554185},
#  {'City': 'talara',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 63.27,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 12.03,
#   'Country': 'PE',
#   'Date': 1667554186},
#  {'City': 'guerrero negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 60.67,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 16.2,
#   'Country': 'MX',
#   'Date': 1667554187},
#  {'City': 'saint-philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 80.19,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.35,
#   'Country': 'RE',
#   'Date': 1667554188},
#  {'City': 'kalga',
#   'Lat': 50.9251,
#   'Lng': 118.898,
#   'Max Temp': 14.58,
#   'Humidity': 89,
#   'Cloudiness': 63,
#   'Wind Speed': 2.86,
#   'Country': 'RU',
#   'Date': 1667554188},
#  {'City': 'trelew',
#   'Lat': -43.249,
#   'Lng': -65.3051,
#   'Max Temp': 66.79,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 19.37,
#   'Country': 'AR',
#   'Date': 1667554190},
#  {'City': 'jinchang',
#   'Lat': 38.4953,
#   'Lng': 102.1739,
#   'Max Temp': 45.54,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 9.31,
#   'Country': 'CN',
#   'Date': 1667554191},
#  {'City': 'narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 43.02,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 19.55,
#   'Country': 'GL',
#   'Date': 1667554192},
#  {'City': 'faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 77.41,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 23.29,
#   'Country': 'PF',
#   'Date': 1667554193},
#  {'City': 'bhikhi',
#   'Lat': 30.0667,
#   'Lng': 75.5333,
#   'Max Temp': 91.36,
#   'Humidity': 22,
#   'Cloudiness': 9,
#   'Wind Speed': 2.44,
#   'Country': 'IN',
#   'Date': 1667554194},
#  {'City': 'ca mau',
#   'Lat': 9.1769,
#   'Lng': 105.15,
#   'Max Temp': 78.39,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.31,
#   'Country': 'VN',
#   'Date': 1667554196},
#  {'City': 'havre-saint-pierre',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 35.96,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': 1667554198},
#  {'City': 'beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 4.95,
#   'Humidity': 93,
#   'Cloudiness': 41,
#   'Wind Speed': 10.71,
#   'Country': 'RU',
#   'Date': 1667554199},
#  {'City': 'aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 13.5,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 15.37,
#   'Country': 'RU',
#   'Date': 1667554200},
#  {'City': 'moengo',
#   'Lat': 5.6167,
#   'Lng': -54.4,
#   'Max Temp': 71.33,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 2.53,
#   'Country': 'SR',
#   'Date': 1667553924},
#  {'City': 'port keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 85.23,
#   'Humidity': 62,
#   'Cloudiness': 4,
#   'Wind Speed': 7.31,
#   'Country': 'AU',
#   'Date': 1667554202},
#  {'City': 'kushalgarh',
#   'Lat': 23.199,
#   'Lng': 74.4507,
#   'Max Temp': 92.57,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 4.59,
#   'Country': 'IN',
#   'Date': 1667554203},
#  {'City': 'imphal',
#   'Lat': 24.8167,
#   'Lng': 93.95,
#   'Max Temp': 82.31,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'IN',
#   'Date': 1667554204},
#  {'City': 'berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 41,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Country': 'NO',
#   'Date': 1667554205},
#  {'City': 'taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 83.1,
#   'Humidity': 11,
#   'Cloudiness': 1,
#   'Wind Speed': 9.26,
#   'Country': 'ML',
#   'Date': 1667554207},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 26.44,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'SJ',
#   'Date': 1667554208},
#  {'City': 'impfondo',
#   'Lat': 1.6381,
#   'Lng': 18.0667,
#   'Max Temp': 81.27,
#   'Humidity': 68,
#   'Cloudiness': 98,
#   'Wind Speed': 1.61,
#   'Country': 'CG',
#   'Date': 1667554209},
#  {'City': 'kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 76.78,
#   'Humidity': 15,
#   'Cloudiness': 42,
#   'Wind Speed': 9.24,
#   'Country': 'SD',
#   'Date': 1667553914},
#  {'City': 'litovko',
#   'Lat': 49.2361,
#   'Lng': 135.1742,
#   'Max Temp': 28.56,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 15.84,
#   'Country': 'RU',
#   'Date': 1667554212},
#  {'City': 'coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 44.55,
#   'Humidity': 87,
#   'Cloudiness': 5,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Date': 1667554213},
#  {'City': 'nantucket',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 57,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': 1667554213},
#  {'City': 'inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 84.18,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'MZ',
#   'Date': 1667554214},
#  {'City': 'mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 82.69,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'MU',
#   'Date': 1667553973},
#  {'City': 'puerto escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 77.56,
#   'Humidity': 86,
#   'Cloudiness': 61,
#   'Wind Speed': 4.29,
#   'Country': 'MX',
#   'Date': 1667554216},
#  {'City': 'upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 25.38,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.5,
#   'Country': 'GL',
#   'Date': 1667554217},
#  {'City': 'saint anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 42.58,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': 1667554218},
#  {'City': 'saint-pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 80.28,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'RE',
#   'Date': 1667554219},
#  {'City': 'solms',
#   'Lat': 50.7667,
#   'Lng': 9.6,
#   'Max Temp': 52.68,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Country': 'DE',
#   'Date': 1667554220},
#  {'City': 'port macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 59.9,
#   'Humidity': 69,
#   'Cloudiness': 9,
#   'Wind Speed': 5.48,
#   'Country': 'AU',
#   'Date': 1667554221},
#  {'City': 'evensk',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': 19.44,
#   'Humidity': 79,
#   'Cloudiness': 82,
#   'Wind Speed': 25.08,
#   'Country': 'RU',
#   'Date': 1667554222},
#  {'City': 'the valley',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp': 81.1,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 13.76,
#   'Country': 'AI',
#   'Date': 1667554223},
#  {'City': 'lafayette',
#   'Lat': 30.2335,
#   'Lng': -92.0668,
#   'Max Temp': 71.55,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': 1667554067},
#  {'City': 'bandar-e lengeh',
#   'Lat': 26.5579,
#   'Lng': 54.8807,
#   'Max Temp': 86.11,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'IR',
#   'Date': 1667554225},
#  {'City': 'sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 39.09,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': 1667554226},
#  {'City': 'atocha',
#   'Lat': -20.9333,
#   'Lng': -66.2333,
#   'Max Temp': 36.61,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 2.98,
#   'Country': 'BO',
#   'Date': 1667554227},
#  {'City': 'wamba',
#   'Lat': 8.9333,
#   'Lng': 8.6,
#   'Max Temp': 89.13,
#   'Humidity': 27,
#   'Cloudiness': 92,
#   'Wind Speed': 4.54,
#   'Country': 'NG',
#   'Date': 1667554228},
#  {'City': 'port blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 84.24,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'IN',
#   'Date': 1667554228},
#  {'City': 'cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -18.24,
#   'Humidity': 94,
#   'Cloudiness': 16,
#   'Wind Speed': 3.71,
#   'Country': 'RU',
#   'Date': 1667554229},
#  {'City': 'paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 33.93,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.7,
#   'Country': 'GL',
#   'Date': 1667554230},
#  {'City': 'berdigestyakh',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': -6.43,
#   'Humidity': 100,
#   'Cloudiness': 77,
#   'Wind Speed': 4.23,
#   'Country': 'RU',
#   'Date': 1667554231},
#  {'City': 'palauig',
#   'Lat': 15.435,
#   'Lng': 119.9045,
#   'Max Temp': 81.72,
#   'Humidity': 83,
#   'Cloudiness': 27,
#   'Wind Speed': 6.69,
#   'Country': 'PH',
#   'Date': 1667554232},
#  {'City': 'davila',
#   'Lat': 18.4726,
#   'Lng': 120.5763,
#   'Max Temp': 76.98,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 18.32,
#   'Country': 'PH',
#   'Date': 1667554233},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 12.36,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': 1667554234},
#  {'City': 'praia da vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 70.05,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 15.3,
#   'Country': 'PT',
#   'Date': 1667554235},
#  {'City': 'san luis',
#   'Lat': -33.295,
#   'Lng': -66.3356,
#   'Max Temp': 62.74,
#   'Humidity': 23,
#   'Cloudiness': 99,
#   'Wind Speed': 13.49,
#   'Country': 'AR',
#   'Date': 1667554236},
#  {'City': 'dudinka',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': 15.62,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 16.98,
#   'Country': 'RU',
#   'Date': 1667554237},
#  {'City': 'jizan',
#   'Lat': 17.3333,
#   'Lng': 42.6667,
#   'Max Temp': 90.54,
#   'Humidity': 48,
#   'Cloudiness': 68,
#   'Wind Speed': 12.03,
#   'Country': 'SA',
#   'Date': 1667554238},
#  {'City': 'kelvington',
#   'Lat': 52.1667,
#   'Lng': -103.5343,
#   'Max Temp': 15.93,
#   'Humidity': 92,
#   'Cloudiness': 43,
#   'Wind Speed': 7.02,
#   'Country': 'CA',
#   'Date': 1667554239},
#  {'City': 'bambous virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 82.65,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'MU',
#   'Date': 1667554241},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 59.88,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': 1667553985},
#  {'City': 'enshi',
#   'Lat': 30.3,
#   'Lng': 109.4833,
#   'Max Temp': 62.71,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'CN',
#   'Date': 1667554243},
#  {'City': 'belaya gora',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': -17.86,
#   'Humidity': 99,
#   'Cloudiness': 31,
#   'Wind Speed': 0.76,
#   'Country': 'RU',
#   'Date': 1667554245},
#  {'City': 'maningrida',
#   'Lat': -12.0667,
#   'Lng': 134.2667,
#   'Max Temp': 85.66,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 11.21,
#   'Country': 'AU',
#   'Date': 1667554246},
#  {'City': 'calama',
#   'Lat': -22.4667,
#   'Lng': -68.9333,
#   'Max Temp': 45.09,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'CL',
#   'Date': 1667554219},
#  {'City': 'maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 30.04,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.85,
#   'Country': 'GL',
#   'Date': 1667554247},
#  {'City': 'sinnamary',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 74.46,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 6.8,
#   'Country': 'GF',
#   'Date': 1667554248},
#  {'City': 'arona',
#   'Lat': 28.0996,
#   'Lng': -16.681,
#   'Max Temp': 70.02,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'ES',
#   'Date': 1667554249},
#  {'City': 'zhaotong',
#   'Lat': 27.3167,
#   'Lng': 103.7167,
#   'Max Temp': 47.57,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Country': 'CN',
#   'Date': 1667554250},
#  {'City': 'asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 51.28,
#   'Humidity': 53,
#   'Cloudiness': 96,
#   'Wind Speed': 4.52,
#   'Country': 'RO',
#   'Date': 1667554251},
#  {'City': 'rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 54.7,
#   'Humidity': 76,
#   'Cloudiness': 25,
#   'Wind Speed': 0.6,
#   'Country': 'UY',
#   'Date': 1667554252},
#  {'City': 'kimamba',
#   'Lat': -6.7833,
#   'Lng': 37.1333,
#   'Max Temp': 94.64,
#   'Humidity': 25,
#   'Cloudiness': 12,
#   'Wind Speed': 3.78,
#   'Country': 'TZ',
#   'Date': 1667554253},
#  {'City': 'san cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 62.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'VE',
#   'Date': 1667554254},
#  {'City': 'deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -12.41,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 1.95,
#   'Country': 'RU',
#   'Date': 1667554255},
#  {'City': 'goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 59.32,
#   'Humidity': 72,
#   'Cloudiness': 44,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Date': 1667554217},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -2.11,
#   'Humidity': 96,
#   'Cloudiness': 55,
#   'Wind Speed': 8.5,
#   'Country': 'RU',
#   'Date': 1667554257},
#  {'City': 'ust-nera',
#   'Lat': 64.5667,
#   'Lng': 143.2,
#   'Max Temp': -3.55,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.42,
#   'Country': 'RU',
#   'Date': 1667554258},
#  {'City': 'poya',
#   'Lat': -21.35,
#   'Lng': 165.15,
#   'Max Temp': 77.99,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 9.66,
#   'Country': 'NC',
#   'Date': 1667554258},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 26.11,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 29.93,
#   'Country': 'US',
#   'Date': 1667554259},
#  {'City': 'rantepao',
#   'Lat': -2.9701,
#   'Lng': 119.8978,
#   'Max Temp': 70.09,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 1.14,
#   'Country': 'ID',
#   'Date': 1667554260},
#  {'City': 'torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 43.57,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Date': 1667554261},
#  {'City': 'katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 63.14,
#   'Humidity': 74,
#   'Cloudiness': 65,
#   'Wind Speed': 18.45,
#   'Country': 'JP',
#   'Date': 1667554262},
#  {'City': 'rabak',
#   'Lat': 13.1809,
#   'Lng': 32.74,
#   'Max Temp': 94.01,
#   'Humidity': 23,
#   'Cloudiness': 5,
#   'Wind Speed': 10.42,
#   'Country': 'SD',
#   'Date': 1667554263},
#  {'City': 'shuyskoye',
#   'Lat': 59.3736,
#   'Lng': 41.0305,
#   'Max Temp': 34.65,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'RU',
#   'Date': 1667554264},
#  {'City': 'martapura',
#   'Lat': -3.4167,
#   'Lng': 114.85,
#   'Max Temp': 77.2,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'ID',
#   'Date': 1667554264},
#  {'City': 'el vigia',
#   'Lat': 8.6219,
#   'Lng': -71.6506,
#   'Max Temp': 74.16,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.11,
#   'Country': 'VE',
#   'Date': 1667554265},
#  {'City': 'baryshivka',
#   'Lat': 50.361,
#   'Lng': 31.3217,
#   'Max Temp': 50.04,
#   'Humidity': 76,
#   'Cloudiness': 83,
#   'Wind Speed': 2.64,
#   'Country': 'UA',
#   'Date': 1667554267},
#  {'City': 'kiunga',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp': 79.02,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 3.09,
#   'Country': 'PG',
#   'Date': 1667554268},
#  {'City': 'ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 57.38,
#   'Humidity': 88,
#   'Cloudiness': 12,
#   'Wind Speed': 5.99,
#   'Country': 'NZ',
#   'Date': 1667554269},
#  {'City': 'manjacaze',
#   'Lat': -24.7117,
#   'Lng': 33.8828,
#   'Max Temp': 87.75,
#   'Humidity': 44,
#   'Cloudiness': 96,
#   'Wind Speed': 5.23,
#   'Country': 'MZ',
#   'Date': 1667554270},
#  {'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 70.2,
#   'Humidity': 93,
#   'Cloudiness': 85,
#   'Wind Speed': 8.34,
#   'Country': 'PT',
#   'Date': 1667554271},
#  {'City': 'okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 28.22,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Country': 'RU',
#   'Date': 1667554271},
#  {'City': 'sosnovka',
#   'Lat': 56.255,
#   'Lng': 51.2842,
#   'Max Temp': 34.99,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 4.56,
#   'Country': 'RU',
#   'Date': 1667554272},
#  {'City': 'tynda',
#   'Lat': 55.1667,
#   'Lng': 124.7167,
#   'Max Temp': 5.65,
#   'Humidity': 97,
#   'Cloudiness': 89,
#   'Wind Speed': 3.4,
#   'Country': 'RU',
#   'Date': 1667554273},
#  {'City': 'leshukonskoye',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 25.21,
#   'Humidity': 78,
#   'Cloudiness': 31,
#   'Wind Speed': 0.89,
#   'Country': 'RU',
#   'Date': 1667554275},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 80.46,
#   'Humidity': 92,
#   'Cloudiness': 39,
#   'Wind Speed': 17.11,
#   'Country': 'US',
#   'Date': 1667554275},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 15.21,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Date': 1667554276},
#  {'City': 'namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 70.88,
#   'Humidity': 68,
#   'Cloudiness': 96,
#   'Wind Speed': 6.53,
#   'Country': 'AO',
#   'Date': 1667554277},
#  {'City': 'marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 85.84,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind Speed': 9.66,
#   'Country': 'YE',
#   'Date': 1667554278},
#  {'City': 'appingedam',
#   'Lat': 53.3217,
#   'Lng': 6.8583,
#   'Max Temp': 51.98,
#   'Humidity': 90,
#   'Cloudiness': 12,
#   'Wind Speed': 5.99,
#   'Country': 'NL',
#   'Date': 1667554280},
#  {'City': 'sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 74.07,
#   'Humidity': 94,
#   'Cloudiness': 14,
#   'Wind Speed': 0,
#   'Country': 'VU',
#   'Date': 1667554281},
#  {'City': 'bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 57.16,
#   'Humidity': 88,
#   'Cloudiness': 11,
#   'Wind Speed': 9.1,
#   'Country': 'US',
#   'Date': 1667554282},
#  {'City': 'alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 81.52,
#   'Humidity': 58,
#   'Cloudiness': 93,
#   'Wind Speed': 12.84,
#   'Country': 'AU',
#   'Date': 1667554282},
#  {'City': 'amos',
#   'Lat': 48.5669,
#   'Lng': -78.1162,
#   'Max Temp': 52.18,
#   'Humidity': 83,
#   'Cloudiness': 50,
#   'Wind Speed': 12.44,
#   'Country': 'CA',
#   'Date': 1667554283},
#  {'City': 'thiruvananthapuram',
#   'Lat': 8.4833,
#   'Lng': 76.9167,
#   'Max Temp': 85.98,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'IN',
#   'Date': 1667554257},
#  {'City': 'upata',
#   'Lat': 8.0086,
#   'Lng': -62.3989,
#   'Max Temp': 70.2,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.19,
#   'Country': 'VE',
#   'Date': 1667554285},
#  {'City': 'bayir',
#   'Lat': 37.2687,
#   'Lng': 28.2167,
#   'Max Temp': 68.52,
#   'Humidity': 21,
#   'Cloudiness': 2,
#   'Wind Speed': 3.85,
#   'Country': 'TR',
#   'Date': 1667554286},
#  {'City': 'biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 79.43,
#   'Humidity': 81,
#   'Cloudiness': 72,
#   'Wind Speed': 1.86,
#   'Country': 'ID',
#   'Date': 1667554287},
#  {'City': 'proletarsk',
#   'Lat': 46.7031,
#   'Lng': 41.7192,
#   'Max Temp': 45.14,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Country': 'RU',
#   'Date': 1667554288},
#  {'City': 'svirstroy',
#   'Lat': 60.7999,
#   'Lng': 33.7248,
#   'Max Temp': 32.79,
#   'Humidity': 78,
#   'Cloudiness': 26,
#   'Wind Speed': 2.28,
#   'Country': 'RU',
#   'Date': 1667554289},
#  {'City': 'nueva imperial',
#   'Lat': -38.7333,
#   'Lng': -72.95,
#   'Max Temp': 52.45,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 1.45,
#   'Country': 'CL',
#   'Date': 1667554290},
#  {'City': 'guarapari',
#   'Lat': -20.6667,
#   'Lng': -40.4975,
#   'Max Temp': 64.89,
#   'Humidity': 76,
#   'Cloudiness': 94,
#   'Wind Speed': 14.2,
#   'Country': 'BR',
#   'Date': 1667554292},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -17.88,
#   'Humidity': 98,
#   'Cloudiness': 6,
#   'Wind Speed': 5.79,
#   'Country': 'RU',
#   'Date': 1667554293},
#  {'City': 'marystown',
#   'Lat': 47.1666,
#   'Lng': -55.1483,
#   'Max Temp': 45.46,
#   'Humidity': 82,
#   'Cloudiness': 19,
#   'Wind Speed': 12.88,
#   'Country': 'CA',
#   'Date': 1667554294},
#  {'City': 'dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 82.04,
#   'Humidity': 67,
#   'Cloudiness': 97,
#   'Wind Speed': 8.72,
#   'Country': 'MV',
#   'Date': 1667554295},
#  {'City': 'isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 75.31,
#   'Humidity': 94,
#   'Cloudiness': 2,
#   'Wind Speed': 2.3,
#   'Country': 'VU',
#   'Date': 1667554296},
#  {'City': 'abu kamal',
#   'Lat': 34.4506,
#   'Lng': 40.9171,
#   'Max Temp': 76.35,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 8.14,
#   'Country': 'SY',
#   'Date': 1667554297},
# ...
#   'Max Temp': 53.73,
#   'Humidity': 86,
#   'Cloudiness': 87,
#   'Wind Speed': 9.26,
#   'Country': 'BR',
#   'Date': 1667554475},
#  {'City': 'agadir',
#   'Lat': 30.4202,
#   'Lng': -9.5982,
#   'Max Temp': 59.45,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.18,
#   'Country': 'MA',
#   'Date': 1667554476},
#  {'City': 'san luis rio colorado',
#   'Lat': 32.4631,
#   'Lng': -114.7767,
#   'Max Temp': 55.58,
#   'Humidity': 41,
#   'Cloudiness': 1,
#   'Wind Speed': 9.71,
#   'Country': 'MX',
#   'Date': 1667554477},
#  {'City': 'buin',
#   'Lat': -33.7333,
#   'Lng': -70.75,
#   'Max Temp': 61.74,
#   'Humidity': 83,
#   'Cloudiness': 92,
#   'Wind Speed': 1.86,
#   'Country': 'CL',
#   'Date': 1667554478},
#  {'City': 'amursk',
#   'Lat': 50.2261,
#   'Lng': 136.8994,
#   'Max Temp': 28.85,
#   'Humidity': 55,
#   'Cloudiness': 50,
#   'Wind Speed': 7.58,
#   'Country': 'RU',
#   'Date': 1667554478},
#  {'City': 'ushtobe',
#   'Lat': 45.2514,
#   'Lng': 77.9838,
#   'Max Temp': 56.12,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'KZ',
#   'Date': 1667554480},
#  {'City': 'baixo guandu',
#   'Lat': -19.5189,
#   'Lng': -41.0158,
#   'Max Temp': 65.26,
#   'Humidity': 81,
#   'Cloudiness': 70,
#   'Wind Speed': 2.93,
#   'Country': 'BR',
#   'Date': 1667554481},
#  {'City': 'shache',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 58.71,
#   'Humidity': 21,
#   'Cloudiness': 9,
#   'Wind Speed': 6.51,
#   'Country': 'CN',
#   'Date': 1667554481},
#  {'City': 'almonte',
#   'Lat': 37.2647,
#   'Lng': -6.5167,
#   'Max Temp': 68.45,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 5.44,
#   'Country': 'ES',
#   'Date': 1667554482},
#  {'City': 'paratinga',
#   'Lat': -12.6906,
#   'Lng': -43.1842,
#   'Max Temp': 67.03,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'BR',
#   'Date': 1667554483},
#  {'City': 'logan',
#   'Lat': 41.7355,
#   'Lng': -111.8344,
#   'Max Temp': 28.65,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Date': 1667554426},
#  {'City': 'brazzaville',
#   'Lat': -4.2658,
#   'Lng': 15.2832,
#   'Max Temp': 79.16,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CG',
#   'Date': 1667554485},
#  {'City': 'virginia beach',
#   'Lat': 36.8529,
#   'Lng': -75.978,
#   'Max Temp': 63.01,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Date': 1667554207},
#  {'City': 'sandy bay',
#   'Lat': -42.913,
#   'Lng': 147.3532,
#   'Max Temp': 55.29,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Date': 1667554486},
#  {'City': 'abha',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 75.02,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'SA',
#   'Date': 1667554260},
#  {'City': 'banjar',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 81.18,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 2.57,
#   'Country': 'ID',
#   'Date': 1667554488},
#  {'City': 'lakes entrance',
#   'Lat': -37.8811,
#   'Lng': 147.981,
#   'Max Temp': 55.17,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 4.43,
#   'Country': 'AU',
#   'Date': 1667554489},
#  {'City': 'nevelsk',
#   'Lat': 46.6733,
#   'Lng': 141.8633,
#   'Max Temp': 37.54,
#   'Humidity': 54,
#   'Cloudiness': 98,
#   'Wind Speed': 21.32,
#   'Country': 'RU',
#   'Date': 1667554490},
#  {'City': 'akdagmadeni',
#   'Lat': 39.6603,
#   'Lng': 35.8836,
#   'Max Temp': 57.54,
#   'Humidity': 40,
#   'Cloudiness': 14,
#   'Wind Speed': 9.22,
#   'Country': 'TR',
#   'Date': 1667554491},
#  {'City': 'samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 83.12,
#   'Humidity': 71,
#   'Cloudiness': 85,
#   'Wind Speed': 9.8,
#   'Country': 'PG',
#   'Date': 1667554492},
#  {'City': 'channel-port aux basques',
#   'Lat': 47.5702,
#   'Lng': -59.1367,
#   'Max Temp': 48.52,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 20.6,
#   'Country': 'CA',
#   'Date': 1667554492},
#  {'City': 'olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 76.73,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Date': 1667554493},
#  {'City': 'chesma',
#   'Lat': 53.8111,
#   'Lng': 60.6533,
#   'Max Temp': 30.42,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 17.18,
#   'Country': 'RU',
#   'Date': 1667554211},
#  {'City': 'atar',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 71.65,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'MR',
#   'Date': 1667554495},
#  {'City': 'tadine',
#   'Lat': -21.55,
#   'Lng': 167.8833,
#   'Max Temp': 76.5,
#   'Humidity': 86,
#   'Cloudiness': 19,
#   'Wind Speed': 14.43,
#   'Country': 'NC',
#   'Date': 1667554496},
#  {'City': 'aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 8.2,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.12,
#   'Country': 'CA',
#   'Date': 1667554498},
#  {'City': 'hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 42.82,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'IS',
#   'Date': 1667554498},
#  {'City': 'colares',
#   'Lat': 38.7992,
#   'Lng': -9.4469,
#   'Max Temp': 59.99,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 14,
#   'Country': 'PT',
#   'Date': 1667554499},
#  {'City': 'healesville',
#   'Lat': -37.65,
#   'Lng': 145.5167,
#   'Max Temp': 58.35,
#   'Humidity': 97,
#   'Cloudiness': 21,
#   'Wind Speed': 2.33,
#   'Country': 'AU',
#   'Date': 1667554500},
#  {'City': 'saint-georges',
#   'Lat': 12.0564,
#   'Lng': -61.7485,
#   'Max Temp': 80.28,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Country': 'GD',
#   'Date': 1667554237},
#  {'City': 'lixourion',
#   'Lat': 38.2019,
#   'Lng': 20.4314,
#   'Max Temp': 71.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'GR',
#   'Date': 1667554501},
#  {'City': 'seymchan',
#   'Lat': 62.8833,
#   'Lng': 152.4333,
#   'Max Temp': 0.79,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'RU',
#   'Date': 1667554502},
#  {'City': 'grand gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 82.8,
#   'Humidity': 76,
#   'Cloudiness': 55,
#   'Wind Speed': 9.33,
#   'Country': 'MU',
#   'Date': 1667554503},
#  {'City': 'sladkovo',
#   'Lat': 55.5284,
#   'Lng': 70.3385,
#   'Max Temp': 38.46,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.29,
#   'Country': 'RU',
#   'Date': 1667554504},
#  {'City': 'nueve de julio',
#   'Lat': -35.4444,
#   'Lng': -60.8831,
#   'Max Temp': 49.96,
#   'Humidity': 96,
#   'Cloudiness': 2,
#   'Wind Speed': 1.01,
#   'Country': 'AR',
#   'Date': 1667554505},
#  {'City': 'flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 62.38,
#   'Humidity': 72,
#   'Cloudiness': 73,
#   'Wind Speed': 5.99,
#   'Country': 'AU',
#   'Date': 1667554506},
#  {'City': 'genhe',
#   'Lat': 50.7833,
#   'Lng': 121.5167,
#   'Max Temp': 17.28,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.75,
#   'Country': 'CN',
#   'Date': 1667554507},
#  {'City': 'bulolo',
#   'Lat': -7.2,
#   'Lng': 146.65,
#   'Max Temp': 71.78,
#   'Humidity': 97,
#   'Cloudiness': 94,
#   'Wind Speed': 1.72,
#   'Country': 'PG',
#   'Date': 1667554508},
#  {'City': 'kasongo-lunda',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 81.09,
#   'Humidity': 74,
#   'Cloudiness': 70,
#   'Wind Speed': 3.69,
#   'Country': 'CD',
#   'Date': 1667554509},
#  {'City': 'zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': -15.32,
#   'Humidity': 96,
#   'Cloudiness': 79,
#   'Wind Speed': 2.3,
#   'Country': 'RU',
#   'Date': 1667554510},
#  {'City': 'jumla',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 61.39,
#   'Humidity': 48,
#   'Cloudiness': 5,
#   'Wind Speed': 6.91,
#   'Country': 'NP',
#   'Date': 1667554511},
#  {'City': 'sierra vista',
#   'Lat': 31.5545,
#   'Lng': -110.3037,
#   'Max Temp': 36.77,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': 1667554466},
#  {'City': 'komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 54.32,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'UZ',
#   'Date': 1667554512},
#  {'City': 'portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 49.62,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 14,
#   'Country': 'US',
#   'Date': 1667554384},
#  {'City': 'kungurtug',
#   'Lat': 50.5994,
#   'Lng': 97.5228,
#   'Max Temp': 23.02,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.78,
#   'Country': 'RU',
#   'Date': 1667554514},
#  {'City': 'gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 79.79,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.75,
#   'Country': 'IL',
#   'Date': 1667554345},
#  {'City': 'dauphin',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 26.74,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 13.8,
#   'Country': 'CA',
#   'Date': 1667554515},
#  {'City': 'senador jose porfirio',
#   'Lat': -2.5908,
#   'Lng': -51.9542,
#   'Max Temp': 75.47,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 3.49,
#   'Country': 'BR',
#   'Date': 1667554516},
#  {'City': 'meiningen',
#   'Lat': 50.5679,
#   'Lng': 10.4152,
#   'Max Temp': 51.75,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.28,
#   'Country': 'DE',
#   'Date': 1667554517},
#  {'City': 'san policarpo',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 81.93,
#   'Humidity': 78,
#   'Cloudiness': 44,
#   'Wind Speed': 6.22,
#   'Country': 'PH',
#   'Date': 1667554518},
#  {'City': 'zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 1.31,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 16.15,
#   'Country': 'RU',
#   'Date': 1667554518},
#  {'City': 'puerto penasco',
#   'Lat': 31.3167,
#   'Lng': -113.5333,
#   'Max Temp': 61.29,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 18.16,
#   'Country': 'MX',
#   'Date': 1667554520},
#  {'City': 'wakkanai',
#   'Lat': 45.4094,
#   'Lng': 141.6739,
#   'Max Temp': 40.98,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 23.02,
#   'Country': 'JP',
#   'Date': 1667554520},
#  {'City': 'methoni',
#   'Lat': 36.8197,
#   'Lng': 21.7049,
#   'Max Temp': 76.86,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 9.4,
#   'Country': 'GR',
#   'Date': 1667554521},
#  {'City': 'vysokogornyy',
#   'Lat': 50.1167,
#   'Lng': 139.15,
#   'Max Temp': 21.09,
#   'Humidity': 72,
#   'Cloudiness': 71,
#   'Wind Speed': 13.94,
#   'Country': 'RU',
#   'Date': 1667554522},
#  {'City': 'pahrump',
#   'Lat': 36.2083,
#   'Lng': -115.9839,
#   'Max Temp': 44.44,
#   'Humidity': 31,
#   'Cloudiness': 3,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Date': 1667554523},
#  {'City': 'tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 74.82,
#   'Humidity': 84,
#   'Cloudiness': 89,
#   'Wind Speed': 19.8,
#   'Country': 'PF',
#   'Date': 1667554524},
#  {'City': 'kalmunai',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 83.07,
#   'Humidity': 72,
#   'Cloudiness': 65,
#   'Wind Speed': 5.23,
#   'Country': 'LK',
#   'Date': 1667554525},
#  {'City': 'winnemucca',
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp': 33.85,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Date': 1667554491},
#  {'City': 'porbandar',
#   'Lat': 21.6422,
#   'Lng': 69.6093,
#   'Max Temp': 96.78,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'IN',
#   'Date': 1667554527},
#  {'City': 'ler',
#   'Lat': 8.3018,
#   'Lng': 30.1418,
#   'Max Temp': 93.92,
#   'Humidity': 25,
#   'Cloudiness': 8,
#   'Wind Speed': 6.76,
#   'Country': 'SS',
#   'Date': 1667554528},
#  {'City': 'te anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 45.54,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.02,
#   'Country': 'NZ',
#   'Date': 1667554528},
#  {'City': 'baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 12.29,
#   'Humidity': 99,
#   'Cloudiness': 73,
#   'Wind Speed': 0.92,
#   'Country': 'RU',
#   'Date': 1667554529},
#  {'City': 'las matas de farfan',
#   'Lat': 18.8731,
#   'Lng': -71.5166,
#   'Max Temp': 68.02,
#   'Humidity': 94,
#   'Cloudiness': 28,
#   'Wind Speed': 1.48,
#   'Country': 'DO',
#   'Date': 1667554530},
#  {'City': 'gimli',
#   'Lat': 50.6336,
#   'Lng': -96.9907,
#   'Max Temp': 23.02,
#   'Humidity': 74,
#   'Cloudiness': 68,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Date': 1667554531},
#  {'City': 'lady frere',
#   'Lat': -31.7031,
#   'Lng': 27.2329,
#   'Max Temp': 77.18,
#   'Humidity': 44,
#   'Cloudiness': 26,
#   'Wind Speed': 3.56,
#   'Country': 'ZA',
#   'Date': 1667554532},
#  {'City': 'ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 33.69,
#   'Humidity': 91,
#   'Cloudiness': 23,
#   'Wind Speed': 16.22,
#   'Country': 'RU',
#   'Date': 1667554533},
#  {'City': 'remanso',
#   'Lat': -9.6179,
#   'Lng': -42.0831,
#   'Max Temp': 72.79,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'BR',
#   'Date': 1667554534},
#  {'City': 'vyazemskiy',
#   'Lat': 47.5378,
#   'Lng': 134.7525,
#   'Max Temp': 27.21,
#   'Humidity': 53,
#   'Cloudiness': 6,
#   'Wind Speed': 10.02,
#   'Country': 'RU',
#   'Date': 1667554534},
#  {'City': 'ouegoa',
#   'Lat': -20.35,
#   'Lng': 164.4333,
#   'Max Temp': 78.46,
#   'Humidity': 79,
#   'Cloudiness': 25,
#   'Wind Speed': 8.16,
#   'Country': 'NC',
#   'Date': 1667554535},
#  {'City': 'bac lieu',
#   'Lat': 9.285,
#   'Lng': 105.7244,
#   'Max Temp': 77.95,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.41,
#   'Country': 'VN',
#   'Date': 1667554536},
#  {'City': 'bodden town',
#   'Lat': 19.2833,
#   'Lng': -81.25,
#   'Max Temp': 79.93,
#   'Humidity': 74,
#   'Cloudiness': 81,
#   'Wind Speed': 19.77,
#   'Country': 'KY',
#   'Date': 1667554537},
#  {'City': 'khiv',
#   'Lat': 41.7543,
#   'Lng': 47.9306,
#   'Max Temp': 48.87,
#   'Humidity': 75,
#   'Cloudiness': 50,
#   'Wind Speed': 7.31,
#   'Country': 'RU',
#   'Date': 1667554538},
#  {'City': 'ninh binh',
#   'Lat': 20.2539,
#   'Lng': 105.975,
#   'Max Temp': 80.29,
#   'Humidity': 53,
#   'Cloudiness': 36,
#   'Wind Speed': 4.9,
#   'Country': 'VN',
#   'Date': 1667554539},
#  {'City': 'tariba',
#   'Lat': 7.8188,
#   'Lng': -72.2243,
#   'Max Temp': 64.13,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.95,
#   'Country': 'VE',
#   'Date': 1667554540},
#  {'City': 'anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 83.3,
#   'Humidity': 74,
#   'Cloudiness': 84,
#   'Wind Speed': 9.93,
#   'Country': 'GH',
#   'Date': 1667554541},
#  {'City': 'sabla',
#   'Lat': 12.7525,
#   'Lng': 4.7077,
#   'Max Temp': 89.64,
#   'Humidity': 16,
#   'Cloudiness': 76,
#   'Wind Speed': 17,
#   'Country': 'NG',
#   'Date': 1667554542},
#  {'City': 'prince rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 44.29,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'CA',
#   'Date': 1667554543},
#  {'City': 'ranong',
#   'Lat': 9.9658,
#   'Lng': 98.6348,
#   'Max Temp': 84.13,
#   'Humidity': 61,
#   'Cloudiness': 78,
#   'Wind Speed': 7.58,
#   'Country': 'TH',
#   'Date': 1667554544},
#  {'City': 'mut',
#   'Lat': 36.6439,
#   'Lng': 33.4389,
#   'Max Temp': 73.42,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 2.17,
#   'Country': 'TR',
#   'Date': 1667554544},
#  {'City': 'yerofey pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 23.16,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'RU',
#   'Date': 1667554546},
#  {'City': 'yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 77.61,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 8.28,
#   'Country': 'AU',
#   'Date': 1667554547},
#  {'City': 'petropavlovsk-kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 32.59,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': 1667554548},
#  {'City': 'barabash',
#   'Lat': 43.2,
#   'Lng': 131.4833,
#   'Max Temp': 31.14,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.41,
#   'Country': 'RU',
#   'Date': 1667554549},
#  {'City': 'jiuquan',
#   'Lat': 39.7432,
#   'Lng': 98.5174,
#   'Max Temp': 46.22,
#   'Humidity': 28,
#   'Cloudiness': 68,
#   'Wind Speed': 9.98,
#   'Country': 'CN',
#   'Date': 1667554549},
#  {'City': 'vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 45.59,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'IS',
#   'Date': 1667554550},
#  {'City': 'koungheul',
#   'Lat': 13.9833,
#   'Lng': -14.8,
#   'Max Temp': 87.35,
#   'Humidity': 15,
#   'Cloudiness': 84,
#   'Wind Speed': 11.01,
#   'Country': 'SN',
#   'Date': 1667554551},
#  {'City': 'padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 81.07,
#   'Humidity': 78,
#   'Cloudiness': 85,
#   'Wind Speed': 5.17,
#   'Country': 'ID',
#   'Date': 1667554304}]

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lat = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]


# Export the City_Data into a csv
city_data_pd.to_csv("output_data_file.csv", index_label="City_ID")

# Show Record Count
city_data_pd.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      atuona  -9.8000 -139.0333     77.09        81          58       14.07
# 1       bluff -46.6000  168.3333     49.91        71          34       27.34
# 2   busselton -33.6500  115.3333     63.77        52          59       14.74
# 3  codrington -38.2667  141.9667     51.96        81          73        5.14
# 4     kabinda  -6.1333   24.4833     80.22        54          90        3.69
#
#   Country        Date
# 0      PF  1667554019
# 1      NZ  1667554020
# 2      AU  1667554022
# 3      AU  1667554023
# 4      CD  1667554026

# %%
len(max_temps)
# Out:
# 559

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lat, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()# date_time =datetime.date(datetime.now())

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lat, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lat, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lat, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lat,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig3.png")
# Show plot.
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lat,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("Fig4.png")
# Show plot.
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()
